# %% [markdown]
# # Read in catalog information from a text file and plot some parameters

# %% [markdown]
# ## Learning Goals
# - Read an ASCII file using astropy.io
#
# - Convert between representations of coordinate components using astropy.coordinates (hours to degrees)
#
# - Make a spherical projection sky plot using matplotlib

# %% [markdown]
# Using astropy.io.ascii for reading ASCII data, astropy.coordinates, and astropy.units for converting RA into decimal degrees, and matplotlib for making color-magnitude diagram and on-sky locations in a Mollweide projection.

# %%
import numpy as np

# Set up matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Reading in, writing, and manipulating tabular data is covered with astropy.table, and ASCII data is covered with astropy.ascii.

# %%
from astropy.io import ascii

# %% [markdown]
# For many cases, it is sufficient to use the ascii.read('filename') function as a black box for reading data from table-formatted text files. By default, this function will try to figure out how your data is formatted/delimited (by default, guess=True).

# %%
tbl = ascii.read()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tbl = ascii.read()
#
# TypeError: read() missing 1 required positional argument: 'table'
